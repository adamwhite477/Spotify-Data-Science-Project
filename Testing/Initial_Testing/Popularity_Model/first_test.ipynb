# %% [markdown]
# ## Import and Initialize

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import json



with open("credentials.json") as infile:
        auth = json.load(infile)
        client_id = auth["client_id"]
        client_secret = auth["client_secret"]

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []
energy = []
instrumentalness = []
key = []
tempo = []
time_sig = []
valence = [] # How happy a song is??? SO COOL
dancebility = []
acousticness = []
artists_and_tracks = []

# %% [markdown]
# ## Select Data and Add to DF

# %%
count = 0
stupid_tracks = 0
for i in range(0,600,50):
    track_results = spotify.search(q='year:2023', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        f = spotify.audio_features(t['id'])
        f = f[0] # this does not work with live recordings
        artists_id = t['artists'][0]['id']
        track_names = t['name']
        artist_and_track = artists_id + track_names # made an attribute that adds the id and track name together
        if f and (t['popularity'] > 0) and (artist_and_track not in artists_and_tracks) and (t["album"]["artists"][0]["name"] != "Various Artists"): # checks if popularity is greater than 0 and if the song is already in the dataset
            artist_name.append(t['artists'][0]['name'])
            artist_id.append(t['artists'][0]['id'])
            track_name.append(t['name'])
            track_id.append(t['id'])
            track_popularity.append(t['popularity'])
            energy.append(f['energy'])
            instrumentalness.append(f["instrumentalness"])
            key.append(f["key"])
            tempo.append(f["tempo"])
            time_sig.append(f["time_signature"])
            valence.append(f["valence"])
            dancebility.append(f["danceability"])
            acousticness.append(f["acousticness"])
            artists_and_tracks.append(artist_and_track)
        else:
            stupid_tracks+= 1
            
        
        

track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 
                         'track_popularity' : track_popularity, 'artist_id' : artist_id,
                         'energy': energy, 'instrumentalness': instrumentalness,
                         'key': key, 'tempo': tempo, 'time_sig': time_sig, 'valence': valence,
                         'danceability': dancebility, 'acousticness': acousticness})

# %% [markdown]
# ## EDA

# %%
unused_tracks = 600 - len(dancebility)
print(unused_tracks)
# Out:
# 286

# %%
track_df[track_df['valence'] < 0.30]
# Out:
#             artist_name                                  track_name  \
# 29          Nicki Minaj                          Red Ruby Da Sleeze
# 40          Miley Cyrus                                       Jaded
# 47           Zach Bryan                 Dawns (feat. Maggie Rogers)
# 51        Morgan Wallen                           Tennessee Numbers
# 54       Eladio Carrion                                 Coco Chanel
# 59        Morgan Wallen                               Keith Whitley
# 74             Gorillaz                  Tormenta (feat. Bad Bunny)
# 79        Morgan Wallen                      Good Girl Gone Missin’
# 81           Juice WRLD                                   The Light
# 85        Morgan Wallen                                     Outlook
# 86             Rod Wave                           Fight The Feeling
# 98                Kanii                                      I Know
# 101      Destroy Lonely                         if looks could kill
# 122             KAROL G                          MAÑANA SERÁ BONITO
# 127       Morgan Wallen                           Don't Think Jesus
# 133  Tyler, The Creator             RUNITUP (feat. Teezo Touchdown)
# 138           Sam Smith                   Unholy (feat. Kim Petras)
# 139    Melanie Martinez                                LIGHT SHOWER
# 142        Clara La San                            In This Darkness
# 143    Melanie Martinez                               FAERIE SOIRÉE
# 146          Kali Uchis                 Fantasy (feat. Don Toliver)
# 165               Kanii                        I Know - PR1SVX Edit
# 168              Polo G               No Time Wasted (feat. Future)
# 170    Melanie Martinez                                  MOON CYCLE
# 173         Sleep Token                               The Summoning
# 174        Lana Del Rey                   Paris, Texas (feat. SYML)
# 178    Melanie Martinez                                     LEECHES
# 184         John Summit                               Where You Are
# 185          Luke Combs                  Growin' Up and Gettin' Old
# 188                d4vd                                   WORTHLESS
# 192                Yeat   Shmunk (feat. YoungBoy Never Broke Again)
# 195        Lana Del Rey                                         A&W
# 198                  NF                                       HAPPY
# 200               Jimin                                    Face-off
# 201  Tyler, The Creator                          EVERYTHING MUST GO
# 208        Lana Del Rey  Let The Light In (feat. Father John Misty)
# 218        Babyface Ray                                  Ron Artest
# 219                P!nk                                   TRUSTFALL
# 221              Hozier                              All Things End
# 223        Dove Cameron           We Go Down Together (with Khalid)
# 234          Kali Uchis          Worth the Wait (feat. Omar Apollo)
# 235               Jimin                                       Alone
# 239                Russ                    NASTY - Extended Version
# 244        Thomas Rhett            Angels (Don’t Always Have Wings)
# 251           Lil Wayne                      She Will (feat. Drake)
# 268            Sam Hunt                                   Outskirts
# 271             OHGEESY                 GEEKALEEK (feat. Cash Kidd)
# 273        Lana Del Rey          Candy Necklace (feat. Jon Batiste)
# 277          Peso Pluma                      Por las Noches - Remix
# 283        Lana Del Rey                             Taco Truck x VB
# 284         Miley Cyrus                                    Wildcard
# 292               Quavo                                   Honey Bun
# 293                JVKE      this is what losing someone feels like
# 296      Rauw Alejandro                                    PUNTO 40
# 303    Melanie Martinez                                      POWDER
# 304                  NF                                        MAMA
# 305         Miley Cyrus                                   Handstand
#
#                    track_id  track_popularity               artist_id  energy  \
# 29   4ZYAU4A2YBtlNdqOUtc7T2                84  0hCNtLu0JehylgoiP8L4Gh   0.733
# 40   3AAY8YicetRPlDAkibHLiS                85  5YGY8feqx7naU7z4HrwZM6   0.593
# 47   42TtHTxWk782ZBiqyOi2d1                80  40ZNYROS4zLfyyBSs2PGe2   0.441
# 51   5NzfnUyVaNrxa2VtoyBWlR                78  4oUHIQIBe0LHzYfvXNW4QM   0.738
# 54   0PB0O24JqAuNdOAFVJljMS                91  5XJDexmWFLWOkjOEjOVX3e   0.764
# 59   1vcJdUJDM2NVXBsGncmLyh                77  4oUHIQIBe0LHzYfvXNW4QM   0.693
# 74   38UYeBLfvpnDSG9GznZdnL                89  3AA28KZvwAUcZuOKwyblJQ   0.768
# 79   5LisHkYlpdkqNYl1HZ5cKd                76  4oUHIQIBe0LHzYfvXNW4QM   0.492
# 81   6j5BK1cFX9TjJd5EXHGgAn                81  4MCBfE4596Uoi2O4DtmEMz   0.844
# 85   3uKJ1sSJXGLCMItH0YNPkh                76  4oUHIQIBe0LHzYfvXNW4QM   0.764
# 86   7l6nGz4gp6HGs5Cvmdeqe4                76  45TgXXqMDdF8BkjA83OM7z   0.538
# 98   2RkMSIqUdveO3p8KVpYBYI                78  1S82w4yw9TYIHZ889mPPaW   0.474
# 146          0.000288   10  104.036         4   0.1880         0.641
# 165          0.472000   11  134.038         4   0.1090         0.674
# 168          0.000000    1  150.035         4   0.1050         0.513
# 170          0.000001    2  154.968         4   0.2270         0.666
# 173          0.004900   10  172.965         4   0.1480         0.395
# 174          0.051200    0  169.690         3   0.1850         0.315
# 178          0.000000   10  140.302         3   0.0638         0.319
# 184          0.005410    9  126.000         4   0.0818         0.560
# 185          0.000005    2  146.051         4   0.2690         0.511
# 188          0.000000    4  124.593         4   0.1530         0.643
# 192          0.000116    7  141.929         4   0.0960         0.744
# 195          0.375000   10  161.468         4   0.1390         0.421
# 198          0.000000    7  106.004         4   0.2210         0.732
# 200          0.000015    2  119.949         4   0.2390         0.689
# 201          0.000007    1   93.098         5   0.2870         0.377
# 208          0.003320    9  132.427         4   0.2020         0.327
# 218          0.000000    1  121.979         4   0.2770         0.836
# 219          0.000216    8  122.032         4   0.2500         0.636
# 221          0.000000    9   74.883         4   0.2360         0.492
# 223          0.000011    9  104.923         3   0.1340         0.494
# 234          0.000000    0  155.900         4   0.2110         0.583
# 235          0.000000    0  102.057         4   0.1680         0.593
# 239          0.000008    5   83.526         4   0.2420         0.819
# 244          0.000153    1   66.041         3   0.2300         0.527
# 251          0.000000    8   98.160         5   0.0782         0.381
# 268          0.000000   10   75.070         4   0.1940         0.552
# 271          0.000012   11  105.007         4   0.1800         0.835
# 273          0.010300   11  116.295         4   0.0799         0.343
# 277          0.000042    9   87.460         3   0.2220         0.656
# 283          0.107000    9  157.862         4   0.0395         0.382
# 284          0.135000    6  109.997         4   0.2320         0.723
# 292          0.000000    1  151.974         4   0.2660         0.752
# 293          0.000000    5  128.577         4   0.2810         0.602
# 296          0.015000    0  106.993         4   0.2080         0.857
# 303          0.000048    7   94.995         4   0.1980         0.602
# 304          0.000000   11   89.386         4   0.0876         0.547
# 305          0.000149   10  183.925         4   0.2400         0.414
#
#      acousticness
# 29       0.115000
# 40       0.047600
# 47       0.874000
# 51       0.048700
# 54       0.042700
# 59       0.088400
# 74       0.458000
# 79       0.316000
# 81       0.076600
# 85       0.034200
# 86       0.051400
# 98       0.486000
# 101      0.024000
# 122      0.455000
# 127      0.525000
# 133      0.565000
# 138      0.011000
# 139      0.742000
# 142      0.841000
# 143      0.434000
# 146      0.129000
# 165      0.078400
# 168      0.006420
# 170      0.867000
# 173      0.001480
# 174      0.985000
# 178      0.645000
# 184      0.009530
# 185      0.160000
# 188      0.068300
# 192      0.020400
# 195      0.665000
# 198      0.306000
# 200      0.178000
# 201      0.806000
# 208      0.344000
# 218      0.158000
# 219      0.001620
# 221      0.378000
# 223      0.652000
# 234      0.725000
# 235      0.283000
# 239      0.027400
# 244      0.063000
# 251      0.000524
# 268      0.215000
# 271      0.005940
# 273      0.871000
# 277      0.237000
# 283      0.625000
# 284      0.116000
# 292      0.017100
# 293      0.825000
# 296      0.001120
# 303      0.369000
# 304      0.284000
# 305      0.089000
