# %% [markdown]
# ## Import and Initialize

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import json



with open("credentials.json") as infile:
        auth = json.load(infile)
        client_id = auth["client_id"]
        client_secret = auth["client_secret"]

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []
energy = []
instrumentalness = []
key = []
tempo = []
time_sig = []
valence = [] # How happy a song is??? SO COOL
dancebility = []
acousticness = []
artists_and_tracks = []

# %% [markdown]
# ## Select Data and Add to DF

# %%
count = 0
stupid_tracks = 0
for i in range(0,600,50):
    track_results = spotify.search(q='year:2023', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        f = spotify.audio_features(t['id'])
        f = f[0] # this does not work with live recordings
        artists_id = t['artists'][0]['id']
        track_names = t['name']
        artist_and_track = artists_id + track_names # made an attribute that adds the id and track name together
        if f and (t['popularity'] > 0) and (artist_and_track not in artists_and_tracks) and (t["album"]["artists"][0]["name"] != "Various Artists"): # checks if popularity is greater than 0 and if the song is already in the dataset
            artist_name.append(t['artists'][0]['name'])
            artist_id.append(t['artists'][0]['id'])
            track_name.append(t['name'])
            track_id.append(t['id'])
            track_popularity.append(t['popularity'])
            energy.append(f['energy'])
            instrumentalness.append(f["instrumentalness"])
            key.append(f["key"])
            tempo.append(f["tempo"])
            time_sig.append(f["time_signature"])
            valence.append(f["valence"])
            dancebility.append(f["danceability"])
            acousticness.append(f["acousticness"])
            artists_and_tracks.append(artist_and_track)
        else:
            stupid_tracks+= 1
            
        
        

track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 
                         'track_popularity' : track_popularity, 'artist_id' : artist_id,
                         'energy': energy, 'instrumentalness': instrumentalness,
                         'key': key, 'tempo': tempo, 'time_sig': time_sig, 'valence': valence,
                         'danceability': dancebility, 'acousticness': acousticness})

# %% [markdown]
# ## EDA

# %%
unused_tracks = 600 - len(dancebility)
print(unused_tracks)
# Out:
# 410

# %%
track_df[track_df['valence'] < 0.30]
# Out:
#        artist_name                                         track_name  \
# 13      Zach Bryan                        Dawns (feat. Maggie Rogers)
# 21   Morgan Wallen                                  Tennessee Numbers
# 26   Morgan Wallen                                      Keith Whitley
# 43   Morgan Wallen                             Good Girl Gone Missin’
# 47   Morgan Wallen                                            Outlook
# 49   Morgan Wallen                                  Don't Think Jesus
# 56    Taylor Swift                                      Lavender Haze
# 59    Lana Del Rey                                                A&W
# 66      The Weeknd                                 Alone Again - Live
# 67      The Weeknd                            Call Out My Name - Live
# 69      The Weeknd                                   The Hills - Live
# 70      The Weeknd                                    Gasoline - Live
# 71      The Weeknd                                 After Hours - Live
# 72      The Weeknd                                     Starboy - Live
# 73      The Weeknd                                   Sacrifice - Live
# 74      The Weeknd                                   Hurricane - Live
# 75      The Weeknd                                   Crew Love - Live
# 76      The Weeknd                               Party Monster - Live
# 79      The Weeknd                                   Heartless - Live
# 82      The Weeknd                                       Intro - Live
# 83      The Weeknd                                      Or Nah - Live
# 87      The Weeknd                                       Faith - Live
# 90      The Weeknd                                   Kiss Land - Live
# 92      The Weeknd                                 The Morning - Live
# 93      The Weeknd                             Save Your Tears - Live
# 95      The Weeknd                             Blinding Lights - Live
# 102     Luke Combs                         Growin' Up and Gettin' Old
# 106           Yeat          Shmunk (feat. YoungBoy Never Broke Again)
# 119    $uicideboy$  Went to Rehab and All I Got Was This Lousy T-S...
# 126         Polo G                      No Time Wasted (feat. Future)
# 129       Gorillaz                         Tormenta (feat. Bad Bunny)
# 132           Yeat                                      Nun id change
# 134    Nicki Minaj                                 Red Ruby Da Sleeze
# 138        KAROL G                                 MAÑANA SERÁ BONITO
# 140      Sam Smith                          Unholy (feat. Kim Petras)
# 142           P!nk                                          TRUSTFALL
# 143   Dove Cameron                  We Go Down Together (with Khalid)
# 149           Yeat                                              Slamm
# 159           Yeat                                   Bad bënd / DëMON
# 162           Yeat                                           Sum 2 do
# 167           Yeat                                           7 nightz
# 172           Yeat                              Now (feat. Luh geeky)
# 173           Yeat                                        Hëavyweight
# 180           Yeat                                          Back homë
# 185           Yeat                                         Dëmon tied
# 189       Skrillex                                             Rumble
#
#                    track_id  track_popularity               artist_id  energy  \
# 13   42TtHTxWk782ZBiqyOi2d1                79  40ZNYROS4zLfyyBSs2PGe2   0.441
# 21   5NzfnUyVaNrxa2VtoyBWlR                73  4oUHIQIBe0LHzYfvXNW4QM   0.738
# 26   1vcJdUJDM2NVXBsGncmLyh                72  4oUHIQIBe0LHzYfvXNW4QM   0.693
# 43   5LisHkYlpdkqNYl1HZ5cKd                69  4oUHIQIBe0LHzYfvXNW4QM   0.492
# 47   3uKJ1sSJXGLCMItH0YNPkh                68  4oUHIQIBe0LHzYfvXNW4QM   0.764
# 49   77qpDGhjN7Hdp12JkPpHvY                67  4oUHIQIBe0LHzYfvXNW4QM   0.416
# 56   5NlYplrGsjUDFZ6x3HeVyT                44  06HL4z0CvFAxyc27GXpf02   0.455
# 59   1wTopxO5eQBpxrBXPSbsUn                81  00FQb4jTyendYWaN8pK0wa   0.248
# 66   2evYKtXNAdn60ANNEdjH7V                56  1Xyo4u8uXC1ZmMpatF05PJ   0.538
# 67   10OyIs6KCOmDO19J5wWFPx                55  1Xyo4u8uXC1ZmMpatF05PJ   0.560
# 69   6N8W7Dbcsg9tRDxn0wjFkR                56  1Xyo4u8uXC1ZmMpatF05PJ   0.789
# 70   2h3ZotklPN6aD7OuHz7bFZ                55  1Xyo4u8uXC1ZmMpatF05PJ   0.833
# 71   7HK0ZDEsW0lGKKIVYvni2z                56  1Xyo4u8uXC1ZmMpatF05PJ   0.502
# 72   4ZYGm4xWPhsZVijqtpWn4C                55  1Xyo4u8uXC1ZmMpatF05PJ   0.845
# 73   7skxtd9x0d05fjz4D7w3t2                55  1Xyo4u8uXC1ZmMpatF05PJ   0.935
# 74   45ypYpAdgoneWcBT0Wba3p                54  1Xyo4u8uXC1ZmMpatF05PJ   0.460
# 75   03H6iCycyxfB2mZzIOEeKJ                54  1Xyo4u8uXC1ZmMpatF05PJ   0.597
# 76   6knNhL3mIaackJvtjmUrfN                54  1Xyo4u8uXC1ZmMpatF05PJ   0.627
# 79   0WrIAsGJOei2FGeakvpTDU                54  1Xyo4u8uXC1ZmMpatF05PJ   0.719
# 26           0.000316    6   83.233         4   0.2280         0.322
# 43           0.000031    7   86.031         4   0.1340         0.558
# 47           0.000068    2  103.001         4   0.2430         0.526
# 49           0.000004    2  116.997         3   0.2450         0.566
# 56           0.000623    8   97.045         4   0.0870         0.736
# 59           0.427000   10  161.667         4   0.1340         0.416
# 66           0.000000    4  112.459         3   0.1560         0.206
# 67           0.000004    2  140.047         3   0.1530         0.403
# 69           0.005220    0  113.130         4   0.0894         0.528
# 70           0.028100   10  123.974         4   0.1630         0.654
# 71           0.000018    5  109.018         4   0.0869         0.645
# 72           0.002290    7  193.989         4   0.1020         0.409
# 73           0.040800    9  123.963         4   0.2930         0.683
# 74           0.087000    2   79.706         4   0.1250         0.246
# 75           0.000000   11  159.827         4   0.1120         0.333
# 76           0.000004    1   78.987         4   0.1840         0.454
# 79           0.000000   10  169.865         4   0.1950         0.587
# 82           0.856000    7  118.121         1   0.0795         0.172
# 83           0.000000    8  136.140         4   0.1720         0.562
# 87           0.000000    0   86.298         4   0.1160         0.305
# 90           0.000000    7   78.410         4   0.1920         0.319
# 92           0.000000    9  129.982         4   0.2690         0.549
# 93           0.019100    0  120.972         4   0.1560         0.573
# 95           0.001840   10  170.910         4   0.0915         0.396
# 102          0.000005    2  146.051         4   0.2690         0.511
# 106          0.000116    7  141.929         4   0.0960         0.744
# 119          0.000039    0  205.432         3   0.1310         0.451
# 126          0.000000    1  150.035         4   0.1050         0.513
# 129          0.001920    0   94.982         4   0.2970         0.637
# 132          0.627000    2  100.003         4   0.1480         0.774
# 134          0.000000    1   98.355         4   0.2920         0.696
# 138          0.000035    8   92.006         4   0.2450         0.777
# 140          0.000003    2  131.199         4   0.2060         0.712
# 142          0.000216    8  122.032         4   0.2500         0.636
# 143          0.000011    9  104.923         3   0.1340         0.494
# 149          0.000000    0  142.035         4   0.1050         0.718
# 159          0.047400    6  136.741         4   0.2000         0.565
# 162          0.000006    9  150.981         4   0.1690         0.720
# 167          0.024500    8  147.959         4   0.2930         0.681
# 172          0.849000    2  133.954         4   0.0946         0.708
# 173          0.273000    0  142.108         4   0.0699         0.645
# 180          0.321000   10  114.008         4   0.2450         0.835
# 185          0.000003    9  150.060         4   0.1300         0.681
# 189          0.229000    1  139.979         4   0.0585         0.810
#
#      acousticness
# 13       0.874000
# 21       0.048700
# 26       0.088400
# 43       0.316000
# 47       0.034200
# 49       0.525000
# 56       0.235000
# 59       0.647000
# 66       0.294000
# 67       0.015700
# 69       0.001320
# 70       0.002490
# 71       0.011300
# 72       0.013400
# 73       0.021200
# 74       0.045300
# 75       0.052300
# 76       0.053200
# 79       0.014700
# 82       0.000004
# 83       0.425000
# 87       0.041100
# 90       0.020900
# 92       0.077500
# 93       0.004110
# 95       0.001350
# 102      0.160000
# 106      0.020400
# 119      0.125000
# 126      0.006420
# 129      0.458000
# 132      0.037000
# 134      0.115000
# 138      0.455000
# 140      0.011000
# 142      0.001620
# 143      0.652000
# 149      0.155000
# 159      0.048800
# 162      0.000088
# 167      0.004290
# 172      0.037400
# 173      0.020500
# 180      0.017100
# 185      0.040600
# 189      0.051500
